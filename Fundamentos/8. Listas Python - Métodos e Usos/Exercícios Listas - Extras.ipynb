# %% [markdown]
# ### Exercício 1
# ### Crie um sistema de cadastro de produtos em uma lista de produtos
# Seu sistema deve:
# - Pegar o usuário qual produto vai ser cadastrado por meio de um input
# - Garantir que se o usuário escrever com letra maiúscula ou minúscula, o produto continua sendo o mesmo produto
# - Se o usuário inserir um produto que já existe na lista, o programa deve printar a mensagem "Produto já existente, tente novamente"
# - Se o usuário inserir um produto que não existe na lista, o programa deve inserir na lista, printar a mensagem Produto X cadastrado com sucesso e em seguida printar a lista completa

# %%
produtos = ["celular", "camera", "fone de ouvido", "monitor"]
novo = input('Digite um PRODUTO que deseja adicionar a lista: ').lower()

if novo in produtos:
    print('Produto já existente, tente novamente!')
else:
    produtos.append(novo)
    print(f'Produto {novo} cadastrado com sucesso.')
    print(f'{produtos}')
# Out:
# Produto tv cadastrado com sucesso.
# ['celular', 'camera', 'fone de ouvido', 'monitor', 'tv']

# %% [markdown]
# ### Exercício 2
# #### Crie um sistema de consulta de preços
# Seu sistema deve:
# - Pedir para o usuário o nome de um produto
# - Caso o produto exista na lista de produtos, o programa deve retornar o preço do produto como resposta
#        - Ex: O produto celular custa R$1500
# - Caso o produto não exista na lista de produtos, o programa deve printar uma mensagem para o usuário tentar novamente

# %%
produtos = ["celular", "camera", "fone de ouvido", "monitor"]
precos = [1500, 1000, 800, 2000]

nome = input('Digite o nome do produto: ').lower()
if nome in produtos:
    posicao = produtos.index(nome)
    print(f'O produto {nome} custa R$ {precos[posicao]:.2f}')
else:
    print('Produto não encontrado, tente novamente!')
# Out:
# O produto camera custa R$ 1000.00

# %% [markdown]
# ### Exercício 3
# #### Crie um sistema de consulta de bônus dos funcionários
# Seu sistema deve:
# - Pegar o valor de vendas do funcionário por meio de um input
# - Calcular o bônus do funcionário de acordo com a seguinte regra:
#       - Se o funcionário vendeu mais de 1000 unidades, ele ganha R$2 de bonus para cada unidade vendida
#       - Se o funcionário vendeu mais de 5000 unidades, ele ganha R$2 de bônus para cada unidade + um valor fixo de R$1000
#       - Se o funcionário vendeu menos de 1000 unidades, ele não ganha bônus
# - Printar no final o valor do bônus do funcionário

# %%
valor = float(input('Digite o a quantidade de vendas: '))
bonus = 0

if valor > 1000 and valor <= 5000:
    bonus = valor * 2
    print(f'O funcinário vendeu mais de 1000 e menos de 5000 quantidades. Com isso seu bônus é {bonus:.2f}')
elif valor > 5000:
    bonus = (valor * 2) + 1000
    print(f'O funcionário vendeu mais de 5000 quantidade, com isso, seu bônus é de {bonus:.2f}')
else: 
    print(f'O funcinário vendeu menos de 1000 quantidade, por isso, NÃO ganha bônus.')
# Out:
# O funcionário vendeu mais de 5000 quantidade, com isso, seu bônus é de 11002.00

# %% [markdown]
# ### Exercício 4
# Crie um programa que consiga descobrir qual dos vendedores vendeu mais
# <br>As vendas dos vendedores são listas com a quantidade vendida por cada vendedor

# %%
vendas = [
    [10, 20, 100, 80, 90, 100, 20, 30, 44, 55, 33, 34, 100, 90, 80, 39, 87, 45, 50, 50, 50, 50, 40, 30, 3, 93, 39, 49, 88],    
    [100, 1, 1, 4, 5, 90, 100, 20, 4, 5, 100, 100, 100, 100, 100, 93, 20, 15, 40, 90, 90, 90, 90, 90, 90, 33, 22, 44, 43, 34],
]
vendedor1 = vendas[0]
vendedor2 = vendas[1]

if sum(vendedor1) > sum(vendedor2):
    print(f'O vendedor 1 vendeu MAIS que o vendedor 2.')
    print(f'Vendedor 1: {sum(vendedor1)} quantidades\nVendedor 2: {sum(vendedor2)} quantidades.')
elif sum(vendedor2) > sum(vendedor1):
    print(f'O vendedor 2 vendeu MAIS que o vendedor 1.')
    print(f'Vendedor 1: {sum(vendedor1)} quantidades\nVendedor 2: {sum(vendedor2)} quantidades.')
else:
    print(f'Empate! Os dois vendedores venderam a mesma quantidade.')
    print(f'Vendedor 1: {sum(vendedor1)} quantidades\nVendedor 2: {sum(vendedor2)} quantidades.')
# Out:
# O vendedor 2 vendeu MAIS que o vendedor 1.
# Vendedor 1: 1599 quantidades
# Vendedor 2: 1714 quantidades.
