# %%
faturamento = float(input("Insira do faturamento: "))
custo =  float(input("Insira o custo: "))

lucro = faturamento - custo

print(f'O lucro foi de R$ {lucro}.')
# Out:
# O lucro foi de R$4500.0.
